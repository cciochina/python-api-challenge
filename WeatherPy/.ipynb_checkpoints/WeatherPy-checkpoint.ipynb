# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key
# print(weather_api_key)

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 604

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# From the website we get this API call
#url = "api.openweathermap.org/data/2.5/weather?q={city name}&appid={API key}"
city_info = []
print("Beginning Data Retrieval")
print("-------------------------")
for index,city in enumerate(cities):
    city_url = f"http://api.openweathermap.org/data/2.5/weather?units=imperial&q={city}&appid={weather_api_key}"
    try:
        data = requests.get(city_url).json()
        print(f"proccesing record number {index} for {city}")
        # Check to see if we can get the weather, if not it should give us an exception
        weather = data["weather"]
        # If we did not get an exception we found data for this city, lets append it
        city_info.append(data)
    except Exception as ex:
        print(f"could not find data for {city}")
print("----------------------------")
print("Data Retrieval Complete")
print("----------------------------")
# Out:
# Beginning Data Retrieval
# -------------------------
# proccesing record number 0 for constitucion
# proccesing record number 1 for tiksi
# proccesing record number 2 for asau
# proccesing record number 3 for rikitea
# proccesing record number 4 for goderich
# proccesing record number 5 for kanganpur
# proccesing record number 6 for albany
# proccesing record number 7 for udachnyy
# proccesing record number 8 for upernavik
# proccesing record number 9 for belushya guba
# could not find data for belushya guba
# proccesing record number 10 for camara de lobos
# proccesing record number 11 for aklavik
# proccesing record number 12 for cuicatlan
# proccesing record number 13 for ushuaia
# proccesing record number 14 for nizhniy odes
# proccesing record number 15 for sola
# proccesing record number 16 for khonuu
# could not find data for khonuu
# proccesing record number 17 for dunedin
# proccesing record number 18 for illoqqortoormiut
# could not find data for illoqqortoormiut
# proccesing record number 19 for bargal
# could not find data for bargal
# proccesing record number 20 for port alfred
# proccesing record number 21 for jahrom
# could not find data for jahrom
# proccesing record number 22 for hobart
# proccesing record number 23 for kruisfontein
# proccesing record number 24 for ponta do sol
# proccesing record number 25 for provideniya
# proccesing record number 26 for dzhusaly
# could not find data for dzhusaly
# proccesing record number 27 for chuy
# proccesing record number 28 for pachelma
# proccesing record number 29 for fare
# proccesing record number 30 for busselton
# proccesing record number 31 for new norfolk
# proccesing record number 32 for mataura
# proccesing record number 33 for menongue
# proccesing record number 34 for bluff
# proccesing record number 35 for markova
# proccesing record number 36 for ajdabiya
# proccesing record number 37 for port elizabeth
# proccesing record number 38 for victoria
# proccesing record number 39 for taolanaro
# could not find data for taolanaro
# proccesing record number 40 for saskylakh
# proccesing record number 41 for baracoa
# proccesing record number 42 for tilichiki
# proccesing record number 43 for northam
# proccesing record number 44 for dikson
# proccesing record number 45 for denpasar
# proccesing record number 46 for cape town
# proccesing record number 47 for boyuibe
# proccesing record number 48 for butaritari
# proccesing record number 49 for portoferraio
# proccesing record number 50 for sao filipe
# proccesing record number 51 for aljezur
# proccesing record number 52 for price
# proccesing record number 53 for nador
# proccesing record number 54 for shambu
# proccesing record number 55 for antalaha
# proccesing record number 56 for haines junction
# proccesing record number 57 for pevek
# proccesing record number 58 for kodiak
# proccesing record number 59 for amderma
# could not find data for amderma
# proccesing record number 60 for qaanaaq
# proccesing record number 61 for liusha
# proccesing record number 62 for fomboni
# proccesing record number 63 for saint george
# proccesing record number 64 for geraldton
# proccesing record number 65 for tasiilaq
# proccesing record number 66 for attawapiskat
# could not find data for attawapiskat
# proccesing record number 67 for axim
# proccesing record number 68 for hambantota
# proccesing record number 69 for castro
# proccesing record number 70 for hermanus
# proccesing record number 71 for georgetown
# proccesing record number 72 for dapaong
# proccesing record number 73 for denizli
# proccesing record number 74 for bethel
# proccesing record number 75 for gemona
# proccesing record number 549 for palaikastron
# proccesing record number 550 for talcahuano
# proccesing record number 551 for saurimo
# proccesing record number 552 for adrar
# proccesing record number 553 for mocuba
# proccesing record number 554 for zhicheng
# proccesing record number 555 for kisesa
# proccesing record number 556 for ust-kuyga
# proccesing record number 557 for epe
# proccesing record number 558 for gazojak
# proccesing record number 559 for belle fourche
# proccesing record number 560 for pacific grove
# proccesing record number 561 for la paz
# proccesing record number 562 for temaraia
# could not find data for temaraia
# proccesing record number 563 for grindavik
# proccesing record number 564 for sivaki
# proccesing record number 565 for rodez
# proccesing record number 566 for zhangye
# proccesing record number 567 for jasper
# proccesing record number 568 for ambilobe
# proccesing record number 569 for waikuku
# proccesing record number 570 for xuddur
# proccesing record number 571 for kerrville
# proccesing record number 572 for ornskoldsvik
# proccesing record number 573 for munxar
# proccesing record number 574 for sisimiut
# proccesing record number 575 for jaisalmer
# proccesing record number 576 for alice springs
# proccesing record number 577 for bose
# proccesing record number 578 for aksarka
# proccesing record number 579 for teguldet
# proccesing record number 580 for diapaga
# proccesing record number 581 for tessalit
# proccesing record number 582 for longyan
# proccesing record number 583 for marcona
# could not find data for marcona
# proccesing record number 584 for ingraj bazar
# proccesing record number 585 for ganzhou
# proccesing record number 586 for hirara
# proccesing record number 587 for poum
# proccesing record number 588 for mozarlandia
# proccesing record number 589 for itupiranga
# proccesing record number 590 for yatou
# proccesing record number 591 for ngukurr
# could not find data for ngukurr
# proccesing record number 592 for karratha
# proccesing record number 593 for khandyga
# proccesing record number 594 for pontian kecil
# proccesing record number 595 for yinchuan
# proccesing record number 596 for vila franca do campo
# proccesing record number 597 for dmitriyevka
# proccesing record number 598 for anzio
# proccesing record number 599 for lazaro cardenas
# proccesing record number 600 for charters towers
# proccesing record number 601 for vanino
# proccesing record number 602 for klyuchi
# proccesing record number 603 for nantucket
# ----------------------------
# Data Retrieval Complete
# ----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_data = []
#[{'coord': {'lon': -25.4333, 'lat': 37.7167},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 294.38,
#    'feels_like': 294.65,
#    'temp_min': 294.38,
#    'temp_max': 294.38,
#    'pressure': 1027,
#    'humidity': 80,
#    'sea_level': 1027,
#    'grnd_level': 1024},
#   'visibility': 10000,
#   'wind': {'speed': 3.03, 'deg': 35, 'gust': 4.48},
#   'clouds': {'all': 0},
#   'dt': 1627939948,
#   'sys': {'type': 1,
#    'id': 6899,
#    'country': 'PT',
#    'sunrise': 1627886775,
#    'sunset': 1627937377},
#   'timezone': 0,
#   'id': 3372472,
#   'name': 'Vila Franca do Campo',
#   'cod': 200},
for data in city_info:
   # City	Lat	Lng	Max Temp	Humidity	Cloudiness	Wind Speed	Country	Date
   # We only need this data
    try:
        city = data["name"]
        lat = data["coord"]["lat"]
        lng = data["coord"]["lon"]
        max_temp = data["main"]["temp_max"]
        humidity = data["main"]["humidity"]
        cloudiness = data["clouds"]["all"]
        wind_speed = data["wind"]["speed"]
        country = data["sys"]["country"]
        date = data["dt"]
        info = {"City": city,
                "Lat": lat,
                "Lng": lng,
                "Max Temp": max_temp,
                "Humidity": humidity,
                "Cloudiness": cloudiness,
                "Wind Speed": wind_speed,
                "Country": country,
                "Date": date}
        city_data.append(info)
    except:
        ...
city_data_df = pd.DataFrame(city_data)
city_data_df.to_csv(output_data_file)
city_data_df.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Constitución -35.3333  -72.4167     57.04        73          97
# 1         Tiksi  71.6872  128.8694     40.89        88          70
# 2          Asău  46.4333   26.4000     77.92        49          16
# 3       Rikitea -23.1203 -134.9692     73.90        74          18
# 4      Goderich  43.7501  -81.7165     83.03        50           0
#
#    Wind Speed Country        Date
# 0        7.29      CL  1628187639
# 1        7.83      RU  1628187640
# 2        4.65      RO  1628187640
# 3       18.23      PF  1628187640
# 4       10.36      CA  1628187641

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
humidity = city_data_df.loc[city_data_df["Humidity"] > 100]
humidity
# Out:
# Empty DataFrame
# Columns: [City, Lat, Lng, Max Temp, Humidity, Cloudiness, Wind Speed, Country, Date]
# Index: []

# %%
#  Get the indices of cities that have humidity over 100%.
indexes = []
if humidity.index.any():
    indexes = humidity.index
    city_data_df = city_data_df.drop(index=indexes)

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
clean_city_data = pd.DataFrame(city_data_df)
clean_city_data
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Constitución -35.3333  -72.4167     57.04        73          97
# 1              Tiksi  71.6872  128.8694     40.89        88          70
# 2               Asău  46.4333   26.4000     77.92        49          16
# 3            Rikitea -23.1203 -134.9692     73.90        74          18
# 4           Goderich  43.7501  -81.7165     83.03        50           0
# ..               ...      ...       ...       ...       ...         ...
# 556  Lázaro Cárdenas  17.9583 -102.2000     76.33        91         100
# 557  Charters Towers -20.1000  146.2667     49.46        42          12
# 558           Vanino  49.0869  140.2543     59.92        99         100
# 559          Klyuchi  52.2667   79.1667     67.53        58          97
# 560        Nantucket  41.2835  -70.0995     73.99        93         100
#
#      Wind Speed Country        Date
# 0          7.29      CL  1628187639
# 1          7.83      RU  1628187640
# 2          4.65      RO  1628187640
# 3         18.23      PF  1628187640
# 4         10.36      CA  1628187641
# ..          ...     ...         ...
# 556        2.06      MX  1628187755
# 557        7.45      AU  1628187870
# 558        2.84      RU  1628187871
# 559        7.63      RU  1628187871
# 560       24.61      US  1628187872
#
# [561 rows x 9 columns]

# %%
# We are gona use a function so we dont repeat the code
from datetime import date
date = date.today()
date = date.strftime("%d/%m/%Y")
def scatter_plot(y, y_label, y_units):
    clean_city_data.plot(kind="scatter", x="Lat",y=y, edgecolor="black", grid = True)
    plt.xlabel("Latitude")
    plt.ylabel(f"{y_label} ({y_units})")
    plt.title(f"City Latitude vs. {y_label} plot ({date})")
    plt.savefig(f"./output_data/Lat_vs_{y_label}.png")
    plt.show()

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
scatter_plot(y="Max Temp", y_label="Max Temperatures", y_units="F")

# %% [markdown]
# As we see in this plot above, as we get closer to the latitude 0 (closer to the Ecuator), the temperatures are higher.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
scatter_plot(y="Humidity", y_label="Humidity", y_units="%")

# %% [markdown]
# As we see in this plot above, most of the cities have higher humidity rather then lower humidity

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
scatter_plot(y="Cloudiness", y_label="Cloudiness", y_units="%")

# %% [markdown]
# We do not see a significant difference in cloudiness based on latitude

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
scatter_plot(y="Wind Speed", y_label="Wind Speed", y_units="mph")

# %% [markdown]
# Most of the cities have a lower rate of wind speed rather than a higher rate.

# %% [markdown]
# ## Linear Regression

# %%
north = clean_city_data[clean_city_data["Lat"]>=0]
south = clean_city_data[clean_city_data["Lat"]<0]
def linear_regression(x_values, y_values, title, y_label, annotate_x_y):
    x_values = x_values
    y_values  = y_values
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    print(f"r-value is: {rvalue}")
    plt.scatter(x_values,y_values, edgecolor = "black")
    # Plot regression line
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq, annotate_x_y, fontsize=15,color="red")

    # Label plot
    plt.title(title)
    plt.xlabel("Latitude")
    plt.ylabel(y_label)
    plt.savefig(f"./output_data/{title}.png")
    plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values_n = north["Lat"]
y_values  = north["Max Temp"]

# Label plot
title = "Northern Hemisphere - Max Temp vs. Latitude Linear Regression"
linear_regression(x_values_n, y_values, title, "Max Temp", (10,40))
# Out:
# r-value is: -0.693111246050836

# %% [markdown]
# 92.8 is the expected MaxTemp value when latitude is 0; Whith every one degree increase in latitude, the MaxTemp value in the Northern Hemisphere decreases by 0.5F. The correlation r value indicated a strong negative correlation between the MaxTemp and the latitude.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values_s = south["Lat"]
y_values  = south["Max Temp"]

# Label plot
title = "Southern Hemisphere - Max Temp vs. Latitude Linear Regression"
linear_regression(x_values_s, y_values, title, "Max Temp", (-50,80))
# Out:
# r-value is: 0.7522216376926316

# %% [markdown]
# 80.71 is the MaxTemp value when the latitude is 0; whith every one degree increase in latidude, the MaxTemp in the Southern Hemisphere increases by 0.71F.  The r correlation value indicated a strong positive correlation between the  MaxTemp and the latidude.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
y_values  = north["Humidity"]

# Label plot
title = "Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression"
linear_regression(x_values_n, y_values, title, "Humidity (%)", (45,15))
# Out:
# r-value is: 0.07432607583170668

# %% [markdown]
# 65.14 is the expected humidity value when latitude is 0. Whith every one degree of latitude increase, the humidity in the Northern Hemisphere increases by 0.08. The r correlation value indicates a very weak, sligthly positive association between humidity and latitude.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
y_values  = south["Humidity"]

# Label plot
title = "Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression"
linear_regression(x_values_s, y_values, title, "Humidity", (-55,45))
# Out:
# r-value is: -0.009998058187761567

# %% [markdown]
# 70.34 is the expected humidity value when latitude is 0. Whith every one degree of latitude increase, the humidity in the Southern Hemisphere decreases by 0.02. The r correlation value indicates a very weak, sligthly negative association between humidity and latitude.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
y_values  = north["Cloudiness"]

# Label plot
title = "Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression"
linear_regression(x_values_n, y_values, title, "Cloudiness", (45,15))
# Out:
# r-value is: -0.0029091090556866146

# %% [markdown]
# 58.14 is the expected cloudiness value when latitude is 0. Whith every one degree of latitude increase, the cloudiness in the Northern Hemisphere decreases by 0.01. The r correlation value indicates a very weak negative association between cloudiness and latitude in the Northern Hemisphere.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
y_values  = south["Cloudiness"]

# Label plot
title = "Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression"
linear_regression(x_values_s, y_values, title, "Cloudiness", (-55,25))
# Out:
# r-value is: 0.060012647448747826

# %% [markdown]
# 59.06 is the expected cloudiness value when latitude is 0. Whith every one degree of latitude increase, the cloudiness in the Southern Hemisphere decreases by 0.16. The r correlation value indicates a weak positive association between cloudiness and latitude in the Southern Hemisphere.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
y_values  = north["Wind Speed"]

# Label plot
title = "Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression"
linear_regression(x_values_n, y_values, title, "Wind Speed", (45,25))
# Out:
# r-value is: -0.05829314184034288

# %% [markdown]
# 8.11 is the expected Wind Speed value when latitude is 0. Whith every one degree of latitude increase, the Wind Speed  in the Northern Hemisphere decreases by 0.02. The r correlation value indicates a weak negative association between  Wind Speed and latitude in the Northern Hemisphere

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
y_values  = south["Wind Speed"]

# Label plot
title = "Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression"
linear_regression(x_values_s, y_values, title, "Wind Speed", (-55,25))
# Out:
# r-value is: -0.11986126802272327

# %% [markdown]
# 7.98 is the expected Wind Speed value when latitude is 0. Whith every one degree of latitude increase, the Wind Speed  in the Southern Hemisphere decreases by 0.05. The r correlation value indicates a negative association between  Wind Speed and latitude in the Southern Hemisphere
